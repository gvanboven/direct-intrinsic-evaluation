# %%
labels = ['General', 'None', 'Not-\nnone', 'High\n freq.', 'Low\n freq.']
syn = [58.1, 27.3, 75, 56.7, 59.4]
coh = [56.7, 51.3, 66.7, 48.1, 63.6]
print(syn)
# Out:
# [58.1, 27.3, 75, 56.7, 59.4]

# %%
plt.figure(figsize=(4,3))
# library
import matplotlib.pyplot as plt
plt.grid(True, linewidth=0.5, axis = 'y', linestyle='-.')
labels = ['General', 'None', 'Not-\nnone', 'High\n freq.', 'Low\n freq.']
syn = [58.1, 27.3, 75, 56.7, 59.4]
# Choose the position of each barplots on the x-axis (space=1,4,3,1)
x_pos = [0, 1.3, 2, 3.3, 4]
x_pos_labels = [0, 1.2, 2.1, 3.2, 4.1]
width = [0.6,0.6,0.6,0.6,0.6]
color = ['mediumseagreen','lightgreen','forestgreen','lightgreen','forestgreen']
# Create bars
plt.bar(x_pos, syn, width = width,color = color, edgecolor='black')

plt.ylabel('Inter-rater agreement %', fontsize=14)

y_labels = [0, 20, 40, 60, 80, 100]
# Create names on the x-axis
plt.xticks(x_pos_labels, labels, fontsize=14)
plt.yticks(y_labels, fontsize=12)
plt.savefig('syn_agreement.png', bbox_inches='tight')
# Show graphic
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(4,3))
plt.grid(True, linewidth=0.5, axis = 'y', linestyle='-.')
labels = ['General', 'None', 'Not-\nnone', 'High\n freq.', 'Low\n freq.']

# Choose the position of each barplots on the x-axis (space=1,4,3,1)
x_pos = [0, 1.3, 2, 3.3, 4]
x_pos_labels = [0, 1.2, 2.1, 3.2, 4.1]
width = [0.6,0.6,0.6,0.6,0.6]
color = ['mediumseagreen','lightgreen','forestgreen','lightgreen','forestgreen']
y_labels = [0, 20, 40, 60, 80, 100]
# Create bars
plt.bar(x_pos, coh, width = width,color = color, edgecolor='black')

#plt.ylabel('Inter-rater agreement %', fontsize=14)
 
# Create names on the x-axis
plt.xticks(x_pos_labels, labels, fontsize=14)
plt.yticks(y_labels, fontsize=12)
plt.savefig('coh_agreement.png', bbox_inches='tight')
# Show graphic
plt.show()
